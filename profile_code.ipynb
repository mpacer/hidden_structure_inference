# %%
import pstats

p =pstats.Stats('results/cprofile4.txt')
p.strip_dirs().sort_stats(-1).print_stats()

p.sort_stats('cumtime').print_stats(100)

# %%
import line_profiler

# %%
lstats = line_profiler.load_stats("run_simulation.py.lprof")
line_profiler.show_text(lstats.timings, lstats.unit)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.087497 s
# File: /Users/cocosci/Dropbox/Work/Berkeley/Projects/Time/hidden_structure_inference/lib/likelihood_calculations_shared_params.py
# Function: logposterior_from_loglik_logsparseprior at line 26
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     26                                               @profile
#     27                                               def logposterior_from_loglik_logsparseprior(self,loglik,sparsity=.5):
#     28         4        86975  21743.8     99.4          logp = log_sparse_graphset_prior(self.graphs,sparsity=sparsity)
#     29         4           10      2.5      0.0          unnormed_logposterior = loglik+logp
#     30         4            2      0.5      0.0          try:
#     31                                                       # np.seterr(all='raise')
#     32         4          267     66.8      0.3              unnormed_logposterior - logsumexp(unnormed_logposterior)
#     33                                                       # np.seterr(over='raise')
#     34                                                   except RuntimeWarning:
#     35                                                       import ipdb; ipdb.set_trace()
#     36
#     37         4          243     60.8      0.3          return unnormed_logposterior - logsumexp(unnormed_logposterior)
#
# Total time: 52.6795 s
# File: /Users/cocosci/Dropbox/Work/Berkeley/Projects/Time/hidden_structure_inference/lib/likelihood_calculations_shared_params.py
# Function: p_graph_given_d at line 39
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     39                                               @profile
#     40                                               def p_graph_given_d(self,graphs,options):
#     41                                                   # sets a catch for all numerical warnings to be treated as errors
#     42                                                   # np.seterr(all='raise')
#     43                                                   # np.seterr(under='raise')
#     44         4           64     16.0      0.0          np.seterr(over='raise')
#     45                                                   """
#     46                                                   options includes
#     47                                                   sparsity: the sparsity argument for the prior
#     48                                                   param_sample_size: the number of parameters to be sampled
#     49                                                   stigma_sample_size: the number of internal states to be sampled
#     50                                                   data_sets: the different data_sets to be evaluated as likelihoods
#     51                                                   data_p: the probability of each data_set in data_sets
#     52                                                   num_data_samps: number of samples of observed data to be considered in the liklihood
#     53                                                   """
#     54         4            4      1.0      0.0          self.graphs = graphs
#     55         4            4      1.0      0.0          self.max_graph = self.graphs[0]
#     56         4            4      1.0      0.0          self.options = options
#     57         4            5      1.2      0.0          num_graphs = len(graphs)
#     58                                                   # loglikelihood = np.empty(len(self.graphs))
#     59         4            5      1.2      0.0          num_params= options["param_sample_size"]
#     60
#     61                                                   # generate 1 complete graph with many data structures shared beneath it
#     62
#     63
#     64         4          261     65.2      0.0          max_graph_params = GraphParams.from_networkx(self.max_graph)
#     65
#     66         4         1263    315.8      0.0          self.param_list = [max_graph_params.sample() for x in range(num_params)]
#     67
#     68                                                   # loglikelihood_by_param = np.array(Parallel(n_jobs = -2,
#     69                                                   #     backend = "multiprocessing", verbose = 10)(
#     70                                                   #     delayed(self._helper_subgraph_loglik)(
#     71                                                   #         max_graph_params.from_dict(params)) for params in self.param_list))
#     72
#     73                                                   # loglikelihood_by_param = np.array(Parallel(n_jobs = -1,
#     74                                                   #     backend = "multiprocessing", verbose = 20)(
#     75                                                   #     delayed(self.subgraph_cross_entropy)(
#     76                                                   #         max_graph_params.from_dict(params)) for params in self.param_list))
#     77
#     78         4            9      2.2      0.0          loglikelihood_by_param = np.array([self.subgraph_cross_entropy(max_graph_params.from_dict(params))
#     79         4     52589966 13147491.5     99.8              for params in self.param_list])
#     80
#     81         4          357     89.2      0.0          loglikelihood = logmeanexp(loglikelihood_by_param,axis=0)
#     82
#     83         4            9      2.2      0.0          sparsity = options["sparsity"]
#     84         4        87553  21888.2      0.2          logposterior = self.logposterior_from_loglik_logsparseprior(loglikelihood,sparsity=sparsity)
#     85
#     86         4           23      5.8      0.0          return graphs,np.exp(logposterior),loglikelihood,self.options,self.param_list
#
# Total time: 52.5898 s
# File: /Users/cocosci/Dropbox/Work/Berkeley/Projects/Time/hidden_structure_inference/lib/likelihood_calculations_shared_params.py
# Function: subgraph_cross_entropy at line 91
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     91                                               @profile
#     92
#     93                                               def subgraph_cross_entropy(self,max_graph_params):
#     94                                                   # sub_graph_params = max_graph_params.subgraph_copy(graph.edges())
#     95
#     96                                                   # stigma_sample_size = options["stigma_sample_size"]
#     97
#     98                                                   # gs_in = GraphStructure.from_networkx(sub_graph_from_edge_type(graph,
#     99                                                   #     edge_types=["hidden_sample"]))
#    100                                                   # gs_out = GraphStructure.from_networkx(sub_graph_from_edge_type(graph,
#    101                                                   #     edge_types=["observed"]))
#    102                                                   # gp_in = max_graph_params.subgraph_copy(gs_in.edges)
#    103                                                   # gp_out = max_graph_params.subgraph_copy(gs_out.edges)
#    104         4            5      1.2      0.0          n = self.options["num_data_samps"]
#    105         4           18      4.5      0.0          q = np.array(self.options["data_probs"])
#    106         4           31      7.8      0.0          δ = np.array(self.options["data_sets"])
#    107
#    108                                                   # note that q*loglik_from_aux_data should be vector)
#    109         4     52589781 13147445.2    100.0          return np.array([n*np.dot(q,self.approx_loglik_from_hidden_states(δ,graph,max_graph_params)) for graph in self.graphs])
#
# Total time: 0.006522 s
# File: /Users/cocosci/Dropbox/Work/Berkeley/Projects/Time/hidden_structure_inference/lib/likelihood_calculations_shared_params.py
# Function: gen_iter_simulations_first_only at line 111
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    111                                               @profile
#    112                                               def gen_iter_simulations_first_only(self, gs_in,gp_in,K):
#    113                                                   # builds a simulation object and then samples returning an M lengthed generator
#    114      1216         5338      4.4     81.8          inner_simul = InnerGraphSimulation(gs_in, gp_in)
#    115      1216         1184      1.0     18.2          return inner_simul.sample_iter_solely_first_events(K)
#
# Total time: 52.2877 s
# File: /Users/cocosci/Dropbox/Work/Berkeley/Projects/Time/hidden_structure_inference/lib/likelihood_calculations_shared_params.py
# Function: approx_loglik_from_hidden_states at line 117
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    117                                               @profile
#    118                                               def approx_loglik_from_hidden_states(self,data_sets,graph,max_graph_params):
#    119      1216         2078      1.7      0.0          K = self.options["stigma_sample_size"]
#    120
#    121      1216         1557      1.3      0.0          gs_in = GraphStructure.from_networkx(sub_graph_from_edge_type(graph,
#    122      1216       900795    740.8      1.7              edge_types=["hidden_sample"]))
#    123      1216       708890    583.0      1.4          gp_in = max_graph_params.subgraph_copy(gs_in.edges)
#    124      1216         2053      1.7      0.0          gs_out = GraphStructure.from_networkx(sub_graph_from_edge_type(graph,
#    125      1216      1106549    910.0      2.1              edge_types=["observed"]))
#    126      1216       636739    523.6      1.2          gp_out = max_graph_params.subgraph_copy(gs_out.edges)
#    127
#    128      1216        15298     12.6      0.0          hidden_states_iter = self.gen_iter_simulations_first_only(gs_in,gp_in,K)
#    129                                                   # hidden_states = self.gen_iter_simulations_first_only(gs_in,gp_in,K)
#    130
#    131                                                   # def tmp_func(data_set):
#    132                                                   #     return [self.loglik_with_hidden_states(
#    133                                                   #             data_set, hidden_state_sample, graph, max_graph_params)
#    134                                                   #             for hidden_state_sample in hidden_states_iter.copy()]
#    135
#    136                                                   # import ipdb; ipdb.set_trace()
#    137
#    138                                                   # return np.array([logmeanexp(np.array(tmp_func(data_set),dtype=np.float))
#    139                                                   #         for data_set in data_sets])
#    140
#    141      1216         4797      3.9      0.0          temp_array = np.empty(shape=(K,data_sets.shape[0]))
#    142    122816      8376342     68.2     16.0          for idx, hidden_state_sample in enumerate(hidden_states_iter):
#    143    121600     40403764    332.3     77.3              temp_array[idx,:] = np.array([self.loglik_with_hidden_states(data_set,hidden_state_sample,gs_out,gp_out) for data_set in data_sets])
#    144
#    145                                                   # import ipdb; ipdb.set_trace()
#    146
#    147      1216       128874    106.0      0.2          return logmeanexp(temp_array,axis=0)
#
# Total time: 36.0357 s
# File: /Users/cocosci/Dropbox/Work/Berkeley/Projects/Time/hidden_structure_inference/lib/likelihood_calculations_shared_params.py
# Function: loglik_with_hidden_states at line 153
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    153                                               @profile
#    154                                               def loglik_with_hidden_states(self, data_set, hidden_state_sample, gs_out,gp_out):
#    155
#    156
#    157    608000       601667      1.0      1.7          return np.sum([self.one_edge_loglik(cause_time, effect_time,psi,r) for
#    158    608000     35434012     58.3     98.3              cause_time, effect_time,psi,r in zip(hidden_state_sample,data_set,gp_out.psi,gp_out.r)])
#
# Total time: 12.76 s
# File: /Users/cocosci/Dropbox/Work/Berkeley/Projects/Time/hidden_structure_inference/lib/likelihood_calculations_shared_params.py
# Function: one_edge_loglik at line 160
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    160                                               @profile
#    161                                               def one_edge_loglik(self, cause_time, effect_time, psi, r, T=4.0):
#    162
#    163                                                   # is this an instantaneous intervention?
#    164   2432000      2416348      1.0     18.9          if cause_time - effect_time == 0:
#    165    608000       299809      0.5      2.3              return 0
#    166
#    167                                                   # if the cause never occurs it occurs at infinity
#    168   1824000      3106182      1.7     24.3          if np.isinf(cause_time):
#    169                                                       # it is certain that the effect will not occur if the cause does not occur
#    170   1227205      1743587      1.4     13.7              if np.isinf(effect_time):
#    171    570181       286278      0.5      2.2                  return 0
#    172                                                       # it is impossible for the effect to occur if the cause does not occur
#    173                                                       # previous check was elif not np.isinf(effect_time) but that must be true given top if statement
#    174                                                       else:
#    175    657024       410378      0.6      3.2                  return -np.inf
#    176
#    177                                                   # if the cause does occur it happens at some time other than infinity
#    178    596795       876269      1.5      6.9          if not np.isinf(cause_time):
#    179
#    180                                                       # if the effect doesn't occur, loglik of no events between cause_time and max_time(T)
#    181    596795       868022      1.5      6.8              if np.isinf(effect_time):
#    182    281019       146271      0.5      1.1                  try:
#    183                                                               # test to make sure that you won't hit underflow
#    184    281019       543538      1.9      4.3                      exp_val = np.exp(-r*(T-cause_time))
#    185                                                           except FloatingPointError:
#    186                                                               # it was a really small number, set it to 0
#    187                                                               exp_val = 0
#    188    281019       319630      1.1      2.5                  return -(psi/r)*(1-exp_val)
#    189
#    190                                                       # if the effect occurred but before the cause_time, that's impossible
#    191    315776       203468      0.6      1.6              elif effect_time < cause_time:
#    192     12432         8004      0.6      0.1                  return -np.inf
#    193                                                       # if the effect occurred, after the cause_time,
#    194                                                       # then loglik of no events from cause_time to effect_time + log of rate function
#    195                                                       else:
#    196    303344       163530      0.5      1.3                  try:
#    197                                                               # test to make sure that you won't hit underflow
#    198    303344       610222      2.0      4.8                      exp_val = np.exp(-r*(effect_time-cause_time))
#    199                                                           except FloatingPointError:
#    200                                                               # it was a really small number, set it to 0
#    201                                                               exp_val = 0
#    202
#    203    303344       758437      2.5      5.9                  return np.log(psi) - (r*(effect_time-cause_time)) - (psi/r)*(1-exp_val)
#
# Total time: 0 s
# File: /Users/cocosci/Dropbox/Work/Berkeley/Projects/Time/hidden_structure_inference/lib/likelihood_calculations_shared_params.py
# Function: loglik_from_aux_data at line 210
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    210                                               @profile
#    211                                               def loglik_from_aux_data(self,data_sets,graph,max_graph_params):
#    212                                                   return np.log(np.array([self.approx_likelihood_from_aux(data_set,
#    213                                                       graph,max_graph_params) for data_set in data_sets]))
#
# Total time: 0 s
# File: /Users/cocosci/Dropbox/Work/Berkeley/Projects/Time/hidden_structure_inference/lib/likelihood_calculations_shared_params.py
# Function: approx_likelihood_from_aux at line 215
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    215                                               @profile
#    216                                               def approx_likelihood_from_aux(self,data_set,graph,max_params):
#    217                                                   K = options["stigma_sample_size"]
#    218
#    219                                                   gs_in = GraphStructure.from_networkx(sub_graph_from_edge_type(graph,
#    220                                                       edge_types=["hidden_sample"]))
#    221                                                   gp_in = max_graph_params.subgraph_copy(gs_in.edges)
#    222
#    223                                                   hidden_states_iter = self.gen_iter_simulations_first_only(gs_in,gp_in,K)
#    224
#    225                                                   return np.mean([likelihood_with_hidden_states(data_set,
#    226                                                       hidden_state_sample,graph,max_params) for hidden_state_sample
#    227                                                       in hidden_states_iter])

# %%
lstats
